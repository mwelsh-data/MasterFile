# %%
import os
import pandas as pd
import numpy as np

# %%
cwd = os.path.abspath('C:\\Users\\mwelsh\\OneDrive - XXXX\\Documents\\Python Scripts\\TX\\Cancelled Draws\\Post Upload') 
files = os.listdir(cwd)  

df = pd.DataFrame()
for file in files:
    if file.endswith('.xlsx'):
        file1 = 'C:\\Users\\mwelsh\\OneDrive - XXXX\\Documents\\Python Scripts\\TX\\Cancelled Draws\\Post Upload\\' + file
        df = df.append(pd.read_excel(file1), ignore_index=True) 
df[:2]

# %%
#Drop Unnecessary Columns
MSPN = df[['INVOICE #',
 'TENANT CASE ID','DRAW ID',
 'DRAW ITEM ID',
 'LANDLORD CASE ID','PAY AMOUNT',
 'FUNDING',
 'PAYMENT TYPE','INVOICE DESCRIPTION','PROGRAM YEAR',
 'OFFSET INVOICE #',]]

MSPN [:4]

list(MSPN.columns.values)

# %%
MSPN.to_csv('C:\\Users\\mwelsh\\OneDrive - XXXX\\Documents\\Python Scripts\\TX\\Cancelled Draws\\MasterList Loaded\\Post Upload PreNote MasterList.csv', index=False)
